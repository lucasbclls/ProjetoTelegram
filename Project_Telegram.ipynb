# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasbclls/ProjetoTelegram/blob/main/Project_Telegram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-telegram-bot
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 669.5/669.5 kB 34.9 MB/s eta 0:00:00
# ...

# %%
import json

# Dados do JSON
NODEBS = {"ESVVE02": {
        "latitude": -20.33811,
        "longitude": -40.29675,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1OlnWRgoZMoHbgHVj36TsuTZevvhcVs8&usp=sharing"
    },
    "ESVVE16": {
        "latitude": -20.33886,
        "longitude": -40.3586,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1OlnWRgoZMoHbgHVj36TsuTZevvhcVs8&usp=sharing"
    },
    "ESCAR19": {
        "latitude": -20.37296,
        "longitude": -40.37109,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1OlnWRgoZMoHbgHVj36TsuTZevvhcVs8&usp=sharing"
    },
    "ESCAR12": {
        "latitude": -20.36993,
        "longitude": -40.35466,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1OlnWRgoZMoHbgHVj36TsuTZevvhcVs8&usp=sharing"
    },
    "ESVVE15": {
        "latitude": -20.35567,
        "longitude": -40.31744,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1OlnWRgoZMoHbgHVj36TsuTZevvhcVs8&usp=sharing"
    },
    "ESVVE26": {
        "latitude": -20.33937,
        "longitude": -40.32044,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1OlnWRgoZMoHbgHVj36TsuTZevvhcVs8&usp=sharing"
    },
    "ESVVE24": {
        "latitude": -20.3475,
        "longitude": -40.3068,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1OlnWRgoZMoHbgHVj36TsuTZevvhcVs8&usp=sharing"
    },
    "ESVVE14": {
        "latitude": -20.33507,
        "longitude": -40.33264,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1OlnWRgoZMoHbgHVj36TsuTZevvhcVs8&usp=sharing"
    },
    "ESVVE04": {
        "latitude": -20.34968,
        "longitude": -40.3219,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1OlnWRgoZMoHbgHVj36TsuTZevvhcVs8&usp=sharing"
    },
    "ESVVE05": {
        "latitude": -20.34987,
        "longitude": -40.35083,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1OlnWRgoZMoHbgHVj36TsuTZevvhcVs8&usp=sharing"
    },
    "ESVVE26": {
        "latitude": -20.33811,
        "longitude": -40.29675,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1OlnWRgoZMoHbgHVj36TsuTZevvhcVs8&usp=sharing"
    },
    "ESVVE06": {
        "latitude": -20.36842,
        "longitude": -40.31002,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1D6SLmO9VwYVsWao1zdPttC-3p9oa1DU&usp=sharing"
    },
    "ESVVE08": {
        "latitude": -20.35616,
        "longitude": -40.29998,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1D6SLmO9VwYVsWao1zdPttC-3p9oa1DU&usp=sharing"
    },
    "ESVVE18": {
        "latitude": -20.33535,
        "longitude": -40.29106,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1D6SLmO9VwYVsWao1zdPttC-3p9oa1DU&usp=sharing"
    },
    "ESVVE09": {
        "latitude": -20.35803,
        "longitude": -40.33289,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1D6SLmO9VwYVsWao1zdPttC-3p9oa1DU&usp=sharing"
    },
    "ESVVEI1": {
        "latitude": -20.34104,
        "longitude": -40.28842,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1D6SLmO9VwYVsWao1zdPttC-3p9oa1DU&usp=sharing"
    },
    "ESVVE07": {
        "latitude": -20.33033,
        "longitude": -40.27475,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1D6SLmO9VwYVsWao1zdPttC-3p9oa1DU&usp=sharing"
    },
    "ES0001F": {
        "latitude": -20.35202,
        "longitude": -40.2977,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1D6SLmO9VwYVsWao1zdPttC-3p9oa1DU&usp=sharing"
    },
    "ESVVE12": {
        "latitude": -20.33913,
        "longitude": -40.28318,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1XOVnZVJn2ORgPqyG9_BA5Vku7pnRRqk&usp=sharing"
    },
    "ESVVE13": {
        "latitude": -20.33709,
        "longitude": -40.30729,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1XOVnZVJn2ORgPqyG9_BA5Vku7pnRRqk&usp=sharing"
    },
    "ESVVE01": {
        "latitude": -20.33326,
        "longitude": -40.2821,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1XOVnZVJn2ORgPqyG9_BA5Vku7pnRRqk&usp=sharing"
    },
    "ESVVE17": {
        "latitude": -20.38075,
        "longitude": -40.32007,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1XOVnZVJn2ORgPqyG9_BA5Vku7pnRRqk&usp=sharing"
    },
    "ESVVE21": {
        "latitude": -20.3443,
        "longitude": -40.2852,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1XOVnZVJn2ORgPqyG9_BA5Vku7pnRRqk&usp=sharing"
    },
    "ESVVE27": {
        "latitude": -20.34683,
        "longitude": -40.3326,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1XOVnZVJn2ORgPqyG9_BA5Vku7pnRRqk&usp=sharing"
    },
    "ESVVE23": {
        "latitude": -20.33483,
        "longitude": -40.30403,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1XOVnZVJn2ORgPqyG9_BA5Vku7pnRRqk&usp=sharing"
    },
    "ESVVE22": {
        "latitude": -20.3673,
        "longitude": -40.30093,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=

        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1ggBCqNRU8twQCLfBejoxGaEiDZcaN08&usp=sharing"
    },
    "ESVVE49": {
        "latitude": -20.36093,
        "longitude": -40.31068,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1ggBCqNRU8twQCLfBejoxGaEiDZcaN08&usp=sharing"
    },
    "ESVVE56": {
        "latitude": -20.35939,
        "longitude": -40.29963,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1ggBCqNRU8twQCLfBejoxGaEiDZcaN08&usp=sharing"
    },
    "ESVVE59": {
        "latitude": -20.35208,
        "longitude": -40.35018,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1ggBCqNRU8twQCLfBejoxGaEiDZcaN08&usp=sharing"
    },
    "ESVVE75": {
        "latitude": -20.33039,
        "longitude": -40.27513,
        "descricao": "SITE",
        "mapa_url": "https://www.google.com/maps/d/edit?mid=1ggBCqNRU8twQCLfBejoxGaEiDZcaN08&usp=sharing"
    }
}

# Salvar o JSON no Colab
with open('pops.json', 'w') as json_file:
    json.dump(NODEBS, json_file)

# %%
import nest_asyncio
import json
from telegram import Update
from telegram.ext import Application, CommandHandler, ContextTypes

# Permitir o uso de asyncio no Google Colab
nest_asyncio.apply()

# Função para carregar o JSON externo
def load_json(file_path):
    try:
        with open(file_path, 'r') as file:
            return json.load(file)
    except Exception as e:
        print(f"Erro ao carregar o arquivo JSON: {e}")
        return {}

# Caminho para o arquivo JSON
JSON_FILE_PATH = 'pops.json'

# Carregar os dados do JSON
NODEBS = load_json(JSON_FILE_PATH)

# Função que responde ao comando /mapa e envia o link do mapa
async def mapa(update: Update, context: ContextTypes.DEFAULT_TYPE):
    try:
        # Capturar o nome do NODEB a partir do comando
        nodeb_key = ' '.join(context.args).upper().strip()  # Exemplo: "ESVVE16"

        # Verificar se o NODEB fornecido está no banco de dados
        if nodeb_key in NODEBS:
            nodeb_info = NODEBS[nodeb_key]
            descricao = nodeb_info.get('descricao', 'Sem descrição disponível')
            latitude = nodeb_info.get('latitude', None)
            longitude = nodeb_info.get('longitude', None)
            mapa_base = nodeb_info.get('mapa_url', None)  # Base do link do mapa

            if latitude and longitude and mapa_base:
                # Personaliza o link do mapa com a localização exata
                mapa_url = f"{mapa_base}&ll={latitude},{longitude}&z=15"

                mensagem = (
                    f"📍 Aqui está o mapa do SITE **{nodeb_key}**:\n"

                    f"🔗 [Acesse o Mapa]({mapa_url})"
                )
            else:
                mensagem = f"❌ O SITE **{nodeb_key}** não possui um mapa configurado corretamente."

            # Enviar a resposta
            await update.message.reply_text(mensagem, parse_mode="Markdown")

        else:
            await update.message.reply_text("❌ NODEB não encontrado! Tente novamente.")

    except Exception as e:
        await update.message.reply_text(f"⚠️ Ocorreu um erro: {e}")

# Função para iniciar o bot
async def start(update: Update, context: ContextTypes.DEFAULT_TYPE):
    await update.message.reply_text(
        "👋 Olá! Use o comando **/mapa** seguido do nome do SITE para ver o mapa com suas rotas.\n"
        "🔹 Exemplo: /mapa ESVVE16"
    )

# Função principal para configurar o bot
async def main():
    TELEGRAM_API_TOKEN = '7653073530:AAGAYjboHK7j5hKfc3GDkcuRMUdm29aWy6s'  # Substitua pelo seu API token do BotFather

    # Inicializar o bot
    application = Application.builder().token(TELEGRAM_API_TOKEN).build()

    # Configurar comandos do bot
    application.add_handler(CommandHandler('start', start))
    application.add_handler(CommandHandler('mapa', mapa))

    # Iniciar o bot
    await application.run_polling()

if __name__ == '__main__':
    import asyncio
    asyncio.run(main())
